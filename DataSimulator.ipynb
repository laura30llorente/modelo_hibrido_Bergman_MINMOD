# %% [markdown]
# # **SIMULADOR SIMGLUCOSE**

# %% [markdown]
# Enlace al repositorio del simulador: https://github.com/jxx123/simglucose

# %% [markdown]
# En este archivo se encuentra la configuración elegida para generar el conjunto de datos con el que se desarrolla el presente trabajo.
#
# Para este trabajo, se ha elegido la simulación de todos los pacientes disponibles, es decir, $30$ sujetos distribuidos en $10$ adultos, $10$ adolescentes y $10$ niños. Cada simulación se desarrolla durante un periodo continuo de $168$ horas ($7$ días completos). Además, existen otras configuraciones como la semilla de aleatoriedad, el sensor de glucosa (Dexcom) y la bomba de infusión de insulina (Insulet).
#
# El directorio `data` contiene toda la información y datos generados por el simulador tras la ejecución de este *notebook*.

# %% [markdown]
# Para la correcta ejecución del *notebook*, es necesario instalar la siguiente librería:

# %%
# %pip install simglucose

# %%
from simglucose.simulation.user_interface import simulate
# Out:
# C:\Users\laura\anaconda3\envs\TFG\Lib\site-packages\gym\envs\registration.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# La obtención de los ficheros CSV se ha llevado a cabo invocando la función principal de la librería (`simulate()`), que muestra una interfaz interactiva para establecer paso a paso las condiciones de la simulación.

# %%
simulate()
# Out:
# Show animation? (y/n)  y
# Use multiple processes? (y/n)  y
# Folder name to save results [default]:  data
# Results will be saved in C:\Users\laura\Documents\UTAD\TFG INSO\Pruebas finales\results\data
# Input simulation time (hr):  168
# Select scnenario:
# [1] Random Scnenario
# [2] Custom Scnenario
# >>> 1
# Input simulation start time (hr):  7
# Simulation start time is set to 2026-04-22 07:00:00.
# Select random seed for random scenario [None]:  42
# Select virtual patients:
# [1] All
# [2] All Adolescents
# [3] All Adults
# [4] All Children
# [5] By ID
# >>>  1
# Select the CGM sensor:
# [1] Dexcom
# [2] GuardianRT
# [3] Navigator
# >>>  1
# Select Random Seed for Sensor Noise [None]:  42
# Select the insulin pump:
# [1] Cozmo
# [2] Insulet
# >>>  2
# Select controller:
# [1] Basal-Bolus Controller
# >>> 1
# Simulation took 3034.910727262497 sec.
#                 70<=BG<=180     BG>180      BG<70    BG>250      BG<50  \
# ...
